# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.13.1

# %%
from keras.models import load_model

# Load the model
model = load_model('model_emergencyNet.h5')
model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 240, 240, 3)]        0         []
#
#  conv2d_0 (Conv2D)           (None, 120, 120, 16)         448       ['input_1[0][0]']
#
#  batchnormalization_0 (Batc  (None, 120, 120, 16)         64        ['conv2d_0[0][0]']
#  hNormalization)
#
#  leakyrelu_0 (LeakyReLU)     (None, 120, 120, 16)         0         ['batchnormalization_0[0][0]']
#
#  conv_2d_redu_1 (Conv2D)     (None, 120, 120, 8)          128       ['leakyrelu_0[0][0]']
#
#  redu_bn_1 (BatchNormalizat  (None, 120, 120, 8)          32        ['conv_2d_redu_1[0][0]']
#  ion)
#
#  leakyrelu_redu_act1 (Leaky  (None, 120, 120, 8)          0         ['redu_bn_1[0][0]']
#  ReLU)
#
#  atrous_depth_conv_1_0 (Dep  (None, 120, 120, 8)          72        ['leakyrelu_redu_act1[0][0]']
#  thwiseConv2D)
#
#  atrous_depth_conv_1_1 (Dep  (None, 120, 120, 8)          72        ['leakyrelu_redu_act1[0][0]']
#  thwiseConv2D)
#
#  atrous_depth_conv_1_2 (Dep  (None, 120, 120, 8)          72        ['leakyrelu_redu_act1[0][0]']
#  thwiseConv2D)
#
#  atrous_bn_1_0 (BatchNormal  (None, 120, 120, 8)          32        ['atrous_depth_conv_1_0[0][0]'
#  ization)                                                           ]
#
#  atrous_bn_1_1 (BatchNormal  (None, 120, 120, 8)          32        ['atrous_depth_conv_1_1[0][0]'
#  ization)                                                           ]
#
#  atrous_bn_1_2 (BatchNormal  (None, 120, 120, 8)          32        ['atrous_depth_conv_1_2[0][0]'
#  ization)                                                           ]
#
#  leakyrelu_atrous_act1_0 (L  (None, 120, 120, 8)          0         ['atrous_bn_1_0[0][0]']
#  eakyReLU)
#
#  leakyrelu_atrous_act1_1 (L  (None, 120, 120, 8)          0         ['atrous_bn_1_1[0][0]']
#  eakyReLU)
#
#  leakyrelu_atrous_act1_2 (L  (None, 120, 120, 8)          0         ['atrous_bn_1_2[0][0]']
#  eakyReLU)
#
#  add_1 (Add)                 (None, 120, 120, 8)          0         ['leakyrelu_redu_act1[0][0]',
#                                                                      'leakyrelu_atrous_act1_0[0][0
#                                                                     ]',
#                                                                      'leakyrelu_atrous_act1_1[0][0
#                                                                     ]',
#                                                                      'leakyrelu_atrous_act1_2[0][0
#                                                                     ]']
#
#  fusion_bn_1 (BatchNormaliz  (None, 120, 120, 8)          32        ['add_1[0][0]']
#  ation)
#
#  conv_2d_1 (Conv2D)          (None, 120, 120, 64)         512       ['fusion_bn_1[0][0]']
#
#  batchnormalization_1 (Batc  (None, 120, 120, 64)         256       ['conv_2d_1[0][0]']
#  hNormalization)
#
#  leakyrelu_1 (LeakyReLU)     (None, 120, 120, 64)         0         ['batchnormalization_1[0][0]']
#
#  maxpooling2d_1 (MaxPooling  (None, 60, 60, 64)           0         ['leakyrelu_1[0][0]']
#  2D)
#
#  conv_2d_redu_2 (Conv2D)     (None, 60, 60, 32)           2048      ['maxpooling2d_1[0][0]']
#
#  redu_bn_2 (BatchNormalizat  (None, 60, 60, 32)           128       ['conv_2d_redu_2[0][0]']
#  ion)
#
#  leakyrelu_redu_act2 (Leaky  (None, 60, 60, 32)           0         ['redu_bn_2[0][0]']
#  ReLU)
#
#  atrous_depth_conv_2_0 (Dep  (None, 60, 60, 32)           288       ['leakyrelu_redu_act2[0][0]']
#  thwiseConv2D)
#
#  atrous_depth_conv_2_1 (Dep  (None, 60, 60, 32)           288       ['leakyrelu_redu_act2[0][0]']
#  thwiseConv2D)
#
#  atrous_depth_conv_2_2 (Dep  (None, 60, 60, 32)           288       ['leakyrelu_redu_act2[0][0]']
#  thwiseConv2D)
#
#  atrous_bn_2_0 (BatchNormal  (None, 60, 60, 32)           128       ['atrous_depth_conv_2_0[0][0]'
#  ization)                                                           ]
#
#  atrous_bn_2_1 (BatchNormal  (None, 60, 60, 32)           128       ['atrous_depth_conv_2_1[0][0]'
#  ization)                                                           ]
#
#  atrous_bn_2_2 (BatchNormal  (None, 60, 60, 32)           128       ['atrous_depth_conv_2_2[0][0]'
#  ization)                                                           ]
#
#  leakyrelu_atrous_act2_0 (L  (None, 60, 60, 32)           0         ['atrous_bn_2_0[0][0]']
#  eakyReLU)
#
#  leakyrelu_atrous_act2_1 (L  (None, 60, 60, 32)           0         ['atrous_bn_2_1[0][0]']
#  eakyReLU)
#
#  leakyrelu_atrous_act2_2 (L  (None, 60, 60, 32)           0         ['atrous_bn_2_2[0][0]']
#  eakyReLU)
#
#  add_2 (Add)                 (None, 60, 60, 32)           0         ['leakyrelu_redu_act2[0][0]',
#                                                                      'leakyrelu_atrous_act2_0[0][0
#                                                                     ]',
#                                                                      'leakyrelu_atrous_act2_1[0][0
#                                                                     ]',
#                                                                      'leakyrelu_atrous_act2_2[0][0
#                                                                     ]']
#
#  fusion_bn_2 (BatchNormaliz  (None, 60, 60, 32)           128       ['add_2[0][0]']
#  ation)
#
#  conv_2d_2 (Conv2D)          (None, 60, 60, 96)           3072      ['fusion_bn_2[0][0]']
#
#  batchnormalization_2 (Batc  (None, 60, 60, 96)           384       ['conv_2d_2[0][0]']
#  hNormalization)
#
#  leakyrelu_2 (LeakyReLU)     (None, 60, 60, 96)           0         ['batchnormalization_2[0][0]']
#
#  maxpooling2d_2 (MaxPooling  (None, 30, 30, 96)           0         ['leakyrelu_2[0][0]']
#  2D)
#
#  conv_2d_redu_3 (Conv2D)     (None, 30, 30, 48)           4608      ['maxpooling2d_2[0][0]']
#
#  redu_bn_3 (BatchNormalizat  (None, 30, 30, 48)           192       ['conv_2d_redu_3[0][0]']
#  ion)
#
#  leakyrelu_redu_act3 (Leaky  (None, 30, 30, 48)           0         ['redu_bn_3[0][0]']
#  ReLU)
#
#  atrous_depth_conv_3_0 (Dep  (None, 30, 30, 48)           432       ['leakyrelu_redu_act3[0][0]']
#  thwiseConv2D)
#
#  atrous_depth_conv_3_1 (Dep  (None, 30, 30, 48)           432       ['leakyrelu_redu_act3[0][0]']
#  thwiseConv2D)
#
#  atrous_depth_conv_3_2 (Dep  (None, 30, 30, 48)           432       ['leakyrelu_redu_act3[0][0]']
#  thwiseConv2D)
#
#  atrous_bn_3_0 (BatchNormal  (None, 30, 30, 48)           192       ['atrous_depth_conv_3_0[0][0]'
#  ization)                                                           ]
#
#  atrous_bn_3_1 (BatchNormal  (None, 30, 30, 48)           192       ['atrous_depth_conv_3_1[0][0]'
#  ization)                                                           ]
#
#  atrous_bn_3_2 (BatchNormal  (None, 30, 30, 48)           192       ['atrous_depth_conv_3_2[0][0]'
#  ization)                                                           ]
#
#  leakyrelu_atrous_act3_0 (L  (None, 30, 30, 48)           0         ['atrous_bn_3_0[0][0]']
#  eakyReLU)
#
#  leakyrelu_atrous_act3_1 (L  (None, 30, 30, 48)           0         ['atrous_bn_3_1[0][0]']
#  eakyReLU)
#
#  leakyrelu_atrous_act3_2 (L  (None, 30, 30, 48)           0         ['atrous_bn_3_2[0][0]']
#  eakyReLU)
#
#  add_3 (Add)                 (None, 30, 30, 48)           0         ['leakyrelu_redu_act3[0][0]',
#                                                                      'leakyrelu_atrous_act3_0[0][0
#                                                                     ]',
#                                                                      'leakyrelu_atrous_act3_1[0][0
#                                                                     ]',
#                                                                      'leakyrelu_atrous_act3_2[0][0
#                                                                     ]']
#
#  fusion_bn_3 (BatchNormaliz  (None, 30, 30, 48)           192       ['add_3[0][0]']
#  ation)
#
#  conv_2d_3 (Conv2D)          (None, 30, 30, 128)          6144      ['fusion_bn_3[0][0]']
#
#  batchnormalization_3 (Batc  (None, 30, 30, 128)          512       ['conv_2d_3[0][0]']
#  hNormalization)
#
#  leakyrelu_3 (LeakyReLU)     (None, 30, 30, 128)          0         ['batchnormalization_3[0][0]']
#
#  maxpooling2d_3 (MaxPooling  (None, 15, 15, 128)          0         ['leakyrelu_3[0][0]']
#  2D)
#
#  conv_2d_redu_4 (Conv2D)     (None, 15, 15, 64)           8192      ['maxpooling2d_3[0][0]']
#
#  redu_bn_4 (BatchNormalizat  (None, 15, 15, 64)           256       ['conv_2d_redu_4[0][0]']
#  ion)
#
#  leakyrelu_redu_act4 (Leaky  (None, 15, 15, 64)           0         ['redu_bn_4[0][0]']
#  ReLU)
#
#  atrous_depth_conv_4_0 (Dep  (None, 15, 15, 64)           576       ['leakyrelu_redu_act4[0][0]']
#  thwiseConv2D)
#
#  atrous_depth_conv_4_1 (Dep  (None, 15, 15, 64)           576       ['leakyrelu_redu_act4[0][0]']
#  thwiseConv2D)
#
#  atrous_depth_conv_4_2 (Dep  (None, 15, 15, 64)           576       ['leakyrelu_redu_act4[0][0]']
#  thwiseConv2D)
#
#  atrous_bn_4_0 (BatchNormal  (None, 15, 15, 64)           256       ['atrous_depth_conv_4_0[0][0]'
#  ization)                                                           ]
#
#  atrous_bn_4_1 (BatchNormal  (None, 15, 15, 64)           256       ['atrous_depth_conv_4_1[0][0]'
#  ization)                                                           ]
#
#  atrous_bn_4_2 (BatchNormal  (None, 15, 15, 64)           256       ['atrous_depth_conv_4_2[0][0]'
#  ization)                                                           ]
#
#  leakyrelu_atrous_act4_0 (L  (None, 15, 15, 64)           0         ['atrous_bn_4_0[0][0]']
#  eakyReLU)
#
#  leakyrelu_atrous_act4_1 (L  (None, 15, 15, 64)           0         ['atrous_bn_4_1[0][0]']
#  eakyReLU)
#
#  leakyrelu_atrous_act4_2 (L  (None, 15, 15, 64)           0         ['atrous_bn_4_2[0][0]']
#  eakyReLU)
#
#  add_4 (Add)                 (None, 15, 15, 64)           0         ['leakyrelu_redu_act4[0][0]',
#                                                                      'leakyrelu_atrous_act4_0[0][0
#                                                                     ]',
#                                                                      'leakyrelu_atrous_act4_1[0][0
#                                                                     ]',
#                                                                      'leakyrelu_atrous_act4_2[0][0
#                                                                     ]']
#
#  fusion_bn_4 (BatchNormaliz  (None, 15, 15, 64)           256       ['add_4[0][0]']
#  ation)
#
#  conv_2d_4 (Conv2D)          (None, 15, 15, 128)          8192      ['fusion_bn_4[0][0]']
#
#  batchnormalization_4 (Batc  (None, 15, 15, 128)          512       ['conv_2d_4[0][0]']
#  hNormalization)
#
#  leakyrelu_4 (LeakyReLU)     (None, 15, 15, 128)          0         ['batchnormalization_4[0][0]']
#
#  dropout_spat_4 (SpatialDro  (None, 15, 15, 128)          0         ['leakyrelu_4[0][0]']
#  pout2D)
#
#  conv_2d_redu_5 (Conv2D)     (None, 15, 15, 64)           8192      ['dropout_spat_4[0][0]']
#
#  redu_bn_5 (BatchNormalizat  (None, 15, 15, 64)           256       ['conv_2d_redu_5[0][0]']
#  ion)
#
#  leakyrelu_redu_act5 (Leaky  (None, 15, 15, 64)           0         ['redu_bn_5[0][0]']
#  ReLU)
#
#  atrous_depth_conv_5_0 (Dep  (None, 15, 15, 64)           576       ['leakyrelu_redu_act5[0][0]']
#  thwiseConv2D)
#
#  atrous_depth_conv_5_1 (Dep  (None, 15, 15, 64)           576       ['leakyrelu_redu_act5[0][0]']
#  thwiseConv2D)
#
#  atrous_depth_conv_5_2 (Dep  (None, 15, 15, 64)           576       ['leakyrelu_redu_act5[0][0]']
#  thwiseConv2D)
#
#  atrous_bn_5_0 (BatchNormal  (None, 15, 15, 64)           256       ['atrous_depth_conv_5_0[0][0]'
#  ization)                                                           ]
#
#  atrous_bn_5_1 (BatchNormal  (None, 15, 15, 64)           256       ['atrous_depth_conv_5_1[0][0]'
#  ization)                                                           ]
#
#  atrous_bn_5_2 (BatchNormal  (None, 15, 15, 64)           256       ['atrous_depth_conv_5_2[0][0]'
#  ization)                                                           ]
#
#  leakyrelu_atrous_act5_0 (L  (None, 15, 15, 64)           0         ['atrous_bn_5_0[0][0]']
#  eakyReLU)
#
#  leakyrelu_atrous_act5_1 (L  (None, 15, 15, 64)           0         ['atrous_bn_5_1[0][0]']
#  eakyReLU)
#
#  leakyrelu_atrous_act5_2 (L  (None, 15, 15, 64)           0         ['atrous_bn_5_2[0][0]']
#  eakyReLU)
#
#  add_5 (Add)                 (None, 15, 15, 64)           0         ['leakyrelu_redu_act5[0][0]',
#                                                                      'leakyrelu_atrous_act5_0[0][0
#                                                                     ]',
#                                                                      'leakyrelu_atrous_act5_1[0][0
#                                                                     ]',
#                                                                      'leakyrelu_atrous_act5_2[0][0
#                                                                     ]']
#
#  fusion_bn_5 (BatchNormaliz  (None, 15, 15, 64)           256       ['add_5[0][0]']
#  ation)
#
#  conv_2d_5 (Conv2D)          (None, 15, 15, 128)          8192      ['fusion_bn_5[0][0]']
#
#  batchnormalization_5 (Batc  (None, 15, 15, 128)          512       ['conv_2d_5[0][0]']
#  hNormalization)
#
#  leakyrelu_5 (LeakyReLU)     (None, 15, 15, 128)          0         ['batchnormalization_5[0][0]']
#
#  dropout_spat_5 (SpatialDro  (None, 15, 15, 128)          0         ['leakyrelu_5[0][0]']
#  pout2D)
#
#  conv_2d_redu_6 (Conv2D)     (None, 15, 15, 64)           8192      ['dropout_spat_5[0][0]']
#
#  redu_bn_6 (BatchNormalizat  (None, 15, 15, 64)           256       ['conv_2d_redu_6[0][0]']
#  ion)
#
#  leakyrelu_redu_act6 (Leaky  (None, 15, 15, 64)           0         ['redu_bn_6[0][0]']
#  ReLU)
#
#  atrous_depth_conv_6_0 (Dep  (None, 15, 15, 64)           576       ['leakyrelu_redu_act6[0][0]']
#  thwiseConv2D)
#
#  atrous_depth_conv_6_1 (Dep  (None, 15, 15, 64)           576       ['leakyrelu_redu_act6[0][0]']
#  thwiseConv2D)
#
#  atrous_depth_conv_6_2 (Dep  (None, 15, 15, 64)           576       ['leakyrelu_redu_act6[0][0]']
#  thwiseConv2D)
#
#  atrous_bn_6_0 (BatchNormal  (None, 15, 15, 64)           256       ['atrous_depth_conv_6_0[0][0]'
#  ization)                                                           ]
#
#  atrous_bn_6_1 (BatchNormal  (None, 15, 15, 64)           256       ['atrous_depth_conv_6_1[0][0]'
#  ization)                                                           ]
#
#  atrous_bn_6_2 (BatchNormal  (None, 15, 15, 64)           256       ['atrous_depth_conv_6_2[0][0]'
#  ization)                                                           ]
#
#  leakyrelu_atrous_act6_0 (L  (None, 15, 15, 64)           0         ['atrous_bn_6_0[0][0]']
#  eakyReLU)
#
#  leakyrelu_atrous_act6_1 (L  (None, 15, 15, 64)           0         ['atrous_bn_6_1[0][0]']
#  eakyReLU)
#
#  leakyrelu_atrous_act6_2 (L  (None, 15, 15, 64)           0         ['atrous_bn_6_2[0][0]']
#  eakyReLU)
#
#  add_6 (Add)                 (None, 15, 15, 64)           0         ['leakyrelu_redu_act6[0][0]',
#                                                                      'leakyrelu_atrous_act6_0[0][0
#                                                                     ]',
#                                                                      'leakyrelu_atrous_act6_1[0][0
#                                                                     ]',
#                                                                      'leakyrelu_atrous_act6_2[0][0
#                                                                     ]']
#
#  fusion_bn_6 (BatchNormaliz  (None, 15, 15, 64)           256       ['add_6[0][0]']
#  ation)
#
#  conv_2d_6 (Conv2D)          (None, 15, 15, 256)          16384     ['fusion_bn_6[0][0]']
#
#  batchnormalization_6 (Batc  (None, 15, 15, 256)          1024      ['conv_2d_6[0][0]']
#  hNormalization)
#
#  leakyrelu_6 (LeakyReLU)     (None, 15, 15, 256)          0         ['batchnormalization_6[0][0]']
#
#  last_sepa_conv (Conv2D)     (None, 15, 15, 5)            1285      ['leakyrelu_6[0][0]']
#
#  last_bn (BatchNormalizatio  (None, 15, 15, 5)            20        ['last_sepa_conv[0][0]']
#  n)
#
#  leakyrelu_last_act (LeakyR  (None, 15, 15, 5)            0         ['last_bn[0][0]']
#  eLU)
#
#  global_average_pooling2d_1  (None, 5)                    0         ['leakyrelu_last_act[0][0]']
#   (GlobalAveragePooling2D)
#
#  classification (Activation  (None, 5)                    0         ['global_average_pooling2d_1[0
#  )                                                                  ][0]']
#
# ==================================================================================================
# Total params: 92033 (359.50 KB)
# Trainable params: 87591 (342.15 KB)
# Non-trainable params: 4442 (17.35 KB)
# __________________________________________________________________________________________________
